# %% [markdown]
# Load and Merge Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Load datasets
benin = pd.read_csv('../data/benin_clean.csv')
sierra = pd.read_csv('../data/sierraleone_clean.csv')
togo = pd.read_csv('../data/togo_clean.csv')

benin['Country'] = 'Benin'
sierra['Country'] = 'Sierra Leone'
togo['Country'] = 'Togo'

all_data = pd.concat([benin, sierra, togo], axis=0)

# %% [markdown]
# Comparison Plots

# %%
# Boxplot for GHI
plt.figure(figsize=(10, 6))
sns.boxplot(x='Country', y='GHI', data=all_data)
plt.title('GHI Distribution by Country')
plt.show()

# %% [markdown]
# Summary Table

# %%
summary = all_data.groupby('Country')[['GHI', 'DNI', 'DHI']].agg(['mean', 'median', 'std'])
print(summary)
# Out:
#                      GHI                            DNI                     \
#                     mean median         std        mean median         std
# Country
# Benin         471.706210  464.0  319.649956  331.756952  311.5  285.594634
# Sierra Leone  382.119386  339.5  286.938362  212.469061   84.3  243.403791
# Togo          446.101556  418.1  316.090821  293.335780  231.6  281.017224
#
#                      DHI
#                     mean median         std
# Country
# Benin         224.899832  210.5  143.788765
# Sierra Leone  225.628479  221.4  144.909087
# Togo          223.547405  209.6  144.162045
